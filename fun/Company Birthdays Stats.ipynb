# %%
# %matplotlib inline

# %%
import os

import matplotlib.dates as mdates
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

pd.options.display.mpl_style = 'default'

# %%
home = os.path.expanduser('~')
data = np.load(os.path.join(home, 'Dropbox/devel/fun/company_bds.npy'))

# %%
pdata = pd.Series(range(len(data)), index=data)

# %%
pdata.head()
# Out:
# 1900-05-22    0
# 1900-12-18    1
# 1900-11-11    2
# 1900-05-10    3
# 1900-09-21    4
# dtype: int64

# %%
pdata.plot(kind='kde')

# %%
pdata.plot(kind='bar')

# %%
pdata.plot()

# %%
ddata = data.tolist()

# %%
plt.hist(mdates.date2num(ddata), bins=12)
# Out:
# (array([ 35.,  32.,  42.,  34.,  45.,  42.,  41.,  35.,  36.,  42.,  43.,
#          33.]),
#  array([ 693596.  ,  693626.25,  693656.5 ,  693686.75,  693717.  ,
#          693747.25,  693777.5 ,  693807.75,  693838.  ,  693868.25,
#          693898.5 ,  693928.75,  693959.  ]),
#  <a list of 12 Patch objects>)
